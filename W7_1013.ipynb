# %% [markdown]
# <a href="https://colab.research.google.com/github/ynebin/class2023Fall/blob/main/W7_1013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## line plot
# used to plot data points and connect them with a continuous line

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# ### custom style

# %%
plt.plot(x, y, color='red', linestyle='--', linewidth=2, label="Sine Wave")
plt.title('Custom Style')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %% [markdown]
# ## scatter plot
# uses dots to represent values for two different numeric variables

# %%
study_hours = [2, 3, 5, 1, 4, 6, 2, 8, 7, 9]
exam_scores = [65, 75, 80, 60, 85, 90, 70, 95, 88, 92]

plt.scatter(study_hours, exam_scores)
plt.title('Simple Scatter Plot')
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.show()

# %% [markdown]
# ## bar plot
# used to display and compare the frequency, count, total, or average of datasets

# %%
products = ['A', 'B', 'C', 'D']
sales = [45000, 65000, 58000, 73000]

plt.bar(products, sales)
plt.xlabel('Products')
plt.ylabel('Sales (in dollars)')
plt.title('Sales Performance by Product')
plt.show()

# %% [markdown]
# ### histogram

# %%
another_exam_scores = [75, 80, 65, 90, 85, 78, 92, 88, 70, 82, 95, 60, 77, 73, 68]

plt.hist(another_exam_scores, bins=5, edgecolor='black')
plt.xlabel('Exam Scores')
plt.ylabel('Frequency')
plt.title('Distribution of Exam Scores')
plt.show()

# %% [markdown]
# ## subplots
#
# multiple plots can be created in a single figure

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

# first subplot
axes[0, 0].plot(x, y, color='blue')
axes[0, 0].set_title('Top Left')

# second subplot
axes[0, 1].scatter(study_hours, exam_scores, color='red')
axes[0, 1].set_title('Top Right')

# third subplot
axes[1, 0].bar(products, sales, color='green')
axes[1, 0].set_title('Bottom Left')

# fourth subplot
axes[1, 1].hist(another_exam_scores, bins=5, color='purple', edgecolor='black')
axes[1, 1].set_title('Bottom Right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## saving and exporting

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.plot(x, y)
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.savefig('/content/drive/My Drive/simple_line.png')
